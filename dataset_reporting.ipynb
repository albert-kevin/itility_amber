# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas_profiling as pp

# %% [markdown]
# ## Loading dataset

# %%
# !ls -al
# Out:
# total 7248
# drwxrwxr-x 8 jovyan  1000    4096 Mar 11 17:54  .
# drwxr-xr-x 1 root   root     4096 Feb 14 16:11  ..
# drwxr-xr-x 4 jovyan users    4096 Mar 11 17:50  .cache
# drwxr-xr-x 3 jovyan users    4096 Mar 11 17:48  .config
# -rw-r--r-- 1 jovyan users    1431 Mar 11 17:51  dataset_reporting.ipynb
# drwxrwxr-x 8 jovyan  1000    4096 Mar 11 17:55  .git
# -rw-r--r-- 1 jovyan users  563091 Mar 11 17:54 'Hackathon Amber 110319.pptx'
# -rw-r--r-- 1 jovyan users  973701 Mar 11 17:54 'Hackathon Amber.zip'
# drwxr-xr-x 2 jovyan users    4096 Mar 11 17:47  .ipynb_checkpoints
# drwxr-xr-x 5 jovyan users    4096 Mar 11 17:47  .ipython
# drwxr-xr-x 3 jovyan users    4096 Mar 11 17:40  .local
# -rw-rw-r-- 1 jovyan  1000      15 Mar 11 17:36  README.md
# -rw-r--r-- 1 jovyan users   11106 Mar 11 17:54  sample_solutions.csv
# -rw-r--r-- 1 jovyan users 5828094 Mar 11 17:54  train.csv

# %%
# !head sample_solutions.csv
# Out:
# "id";"checkouts"
# 50997;1
# 50998;1
# 50999;1
# 51000;1
# 51001;1
# 51002;1
# 51003;1
# 51004;1
# 51005;1

# %%
# !head train.csv
# Out:
# "id";"year";"month";"day";"day_part";"start_hub_id";"weekday";"week";"checkouts";"reservations";"checkout_min12h";"checkout_min24h";"checkout_min1w";"checkout_min2w";"checkout_min3w";"checkout_min4w";"temp";"rain";"is_holiday";"holidays_in_week";"zuid_school";"midden_school";"noord_school"
# 1;2018;5;14;2;"832559d3-0101-4ee2-ae1f-8273e150bfc8";1;20;0;0;0;0;0;0;0;0;14,2;0;FALSE;1;FALSE;FALSE;FALSE
# 2;2018;5;14;2;"49afdc25-bf89-463d-93b1-83e652a69447";1;20;0;0;0;0;0;0;0;0;14,2;0;FALSE;1;FALSE;FALSE;FALSE
# 3;2018;5;14;2;"ca4deada-6357-11e7-a856-0050569e4259";1;20;1;1;0;0;0;0;0;0;14,2;0;FALSE;1;FALSE;FALSE;FALSE
# 4;2018;5;14;2;"f7e56e86-8993-4cbd-a471-519da9027580";1;20;0;0;0;0;0;0;0;0;14,2;0;FALSE;1;FALSE;FALSE;FALSE
# 5;2018;5;14;2;"df5ca252-a1c5-4190-a9fa-40a68d482769";1;20;0;0;0;0;0;0;0;0;14,2;0;FALSE;1;FALSE;FALSE;FALSE
# 6;2018;5;14;2;"6cd04ad0-d4a2-4c43-af7e-bcfd9c35e08f";1;20;0;0;0;0;0;0;0;0;14,2;0;FALSE;1;FALSE;FALSE;FALSE
# 7;2018;5;14;2;"8b6e0089-12cb-4471-af91-c3bf2d95c966";1;20;0;0;0;0;0;0;0;0;14,2;0;FALSE;1;FALSE;FALSE;FALSE
# 8;2018;5;14;2;"f4dfbad2-c37d-4287-94e4-b48ae2a77c7c";1;20;0;0;0;0;0;0;0;0;14,2;0;FALSE;1;FALSE;FALSE;FALSE
# 9;2018;5;14;2;"732c56f7-a74d-4174-b4e0-5377b4196b0f";1;20;0;0;0;0;0;0;0;0;14,2;0;FALSE;1;FALSE;FALSE;FALSE

# %%
df = pd.read_csv("train.csv", delimiter=";")

# %%
df.sample(5).T
# Out:
#                                                  29340  \
# id                                               29341
# year                                              2018
# month                                               10
# day                                                 27
# day_part                                             4
# start_hub_id      cc6eead4-9f17-4344-8e14-4df8d2be35a5
# weekday                                              6
# week                                                43
# checkouts                                            0
# reservations                                         0
# checkout_min12h                                      0
# checkout_min24h                                      0
# checkout_min1w                                       0
# checkout_min2w                                       0
# checkout_min3w                                       0
# checkout_min4w                                       0
# temp                                                 4
# rain                                                 0
# is_holiday                                       False
# holidays_in_week                                     0
# zuid_school                                      False
# midden_school                                     True
# noord_school                                      True
#
#                                                  15944  \
# id                                               15945
# year                                              2018
# month                                                8
# day                                                 12
# day_part                                             4
# start_hub_id      b8e69830-2432-476c-8deb-686194b27434
# weekday                                              0
# week                                                32
# checkouts                                            0
# reservations                                         0
# checkout_min12h                                      0
# checkout_min24h                                      0
# checkout_min1w                                       0
# checkout_min2w                                       0
# checkout_min3w                                       0
# checkout_min4w                                       0
# temp                                             20,75
# rain                                                 0
# is_holiday                                       False
# holidays_in_week                                     0
# zuid_school                                       True
# midden_school                                     True
# noord_school                                      True
#
#                                                  9735   \
# id                                                9736
# year                                              2018
# month                                                7
# day                                                  8
# day_part                                             3
# start_hub_id      cc6eead4-9f17-4344-8e14-4df8d2be35a5
# weekday                                              0
# week                                                27
# checkouts                                            0
# reservations                                         0
# checkout_min12h                                      0
# checkout_min24h                                      0
# checkout_min1w                                       0
# checkout_min2w                                       0
# checkout_min3w                                       0
# checkout_min4w                                       0
# temp                                              24,5
# rain                                                 0
# is_holiday                                       False
# holidays_in_week                                     0
# zuid_school                                       True
# midden_school                                    False
# noord_school                                     False
#
#                                                  33114  \
# id                                               33115
# year                                              2018
# month                                               11
# day                                                 18
# day_part                                             2
# start_hub_id      f7e56e86-8993-4cbd-a471-519da9027580
# weekday                                              0
# week                                                46
# checkouts                                            0
# reservations                                         0
# checkout_min12h                                      0
# checkout_min24h                                      0
# checkout_min1w                                       0
# checkout_min2w                                       0
# checkout_min3w                                       0
# checkout_min4w                                       0
# temp                                                 2
# rain                                                 0
# is_holiday                                       False
# holidays_in_week                                     0
# zuid_school                                      False
# midden_school                                    False
# noord_school                                     False
#
#                                                  13109
# id                                               13110
# year                                              2018
# month                                                7
# day                                                 27
# day_part                                             3
# start_hub_id      6b3ceafc-f10f-46a3-a5b0-6c86e95a3a68
# weekday                                              5
# week                                                30
# checkouts                                            0
# reservations                                         0
# checkout_min12h                                      0
# checkout_min24h                                      0
# checkout_min1w                                       0
# checkout_min2w                                       0
# checkout_min3w                                       0
# checkout_min4w                                       0
# temp                                              34,5
# rain                                                 0
# is_holiday                                       False
# holidays_in_week                                     0
# zuid_school                                       True
# midden_school                                     True
# noord_school                                      True

# %%
# advanced way for df.describe()
pp.ProfileReport(df).to_file('report.html')

# %%
help(tsfresh)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cde02469fc2c> in <module>
# ----> 1 help(tsfresh)
#       2
#
# NameError: name 'tsfresh' is not defined
